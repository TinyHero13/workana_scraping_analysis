# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
columns = ['Title', 
           'Price', 
           'Description', 
           'Skills', 
           'Published',
           'Bids']

df = pd.DataFrame(columns=columns)

# %%
driver = webdriver.Chrome()

def scroll_to_element_if_not_visible(driver, element):
    if not element.is_displayed():
        driver.execute_script("arguments[0].scrollIntoView(true);", element)
    
def wait_and_click_element(vire_more_xpath):
    element = None
    while True:
        try:
            element = driver.find_element(By.XPATH, vire_more_xpath)
            if element.is_displayed() and element.is_enabled():
                element.click()
                break
        except:
            time.sleep(4)
    if not element:
        print(f'não achou elemento {vire_more_xpath}')

for page_num in range(1, 50):
    
    url = f'https://www.workana.com/jobs?language=pt&page={page_num}'
    driver.get(url)
    
    if page_num == 1:
        driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click()
        time.sleep(4)
        driver.find_element(By.XPATH, '//*[@id="app"]/div/div[4]/div/div/button/span').click()
        time.sleep(2)
        
    max_projects = len(driver.find_elements(By.XPATH, '//*[@id="projects"]/div'))

            
    for projects_num in range(1, max_projects + 1):
        project_xpath = f'//*[@id="projects"]/div[{projects_num}]'
        
        time.sleep(3)
        projects_element = driver.find_element(By.XPATH, f'{project_xpath}')
        scroll_to_element_if_not_visible(driver, projects_element)
        
        time.sleep(5)
        
        view_more_xpath = f'{project_xpath}/div[2]/div[2]/div/p/a'
        wait_and_click_element(view_more_xpath)
        time.sleep(4)
        
        
         
        title = driver.find_element(By.XPATH, f'{project_xpath}/div[1]/h2/span/a/span').text
        price = driver.find_element(By.XPATH, f'{project_xpath}/div[4]/h4/span/span').text
        description = driver.find_element(By.XPATH, f'{project_xpath}/div[2]/div[2]/div/p/span').text

        try:
            skills = driver.find_element(By.XPATH, f'{project_xpath}/div[2]/div[3]/div').text
        except:
            skills = 'N/A'
        published = driver.find_element(By.XPATH, f'{project_xpath}/div[2]/div[1]/span[1]').text.split('Publicado: ')[-1]
        bids = driver.find_element(By.XPATH, f'{project_xpath}/div[2]/div[1]/span[2]').text.split('Propostas: ')[-1]
        
        new_row = {
            'Title': title,
            'Price': price,
            'Description': description,
            'Skills': skills,
            'Published': published,
            'Bids': bids
        }
        df = pd.concat([df, pd.DataFrame([new_row])], ignore_index=True)

        print(f'Raspagem do conteúdo: {projects_num} da página: {page_num} finalizada!')
    
driver.quit()

df['DescriptionBottom'] =  df['Description'].apply(lambda x: ''.join(x.split('\n\nCategoria: ')[-1]))
df['SubCategory'] =  df['DescriptionBottom'].apply(lambda x: (x.split('Subcategoria: ')[0].split('\n')[0]))
df['Category'] =  df['DescriptionBottom'].apply(lambda x: (x.split('\n',1)[0]))
df['Description'] = df['Description'].apply(lambda x: ' '.join(x.split('\n\nCategoria')[0].split('\n')).strip())
df['Skills'] = df['Skills'].apply(lambda x: ','.join(x.split('\n')))
# Out:
# Raspagem do conteúdo: 1 da página: 1 finalizada!
# Raspagem do conteúdo: 2 da página: 1 finalizada!
# Raspagem do conteúdo: 3 da página: 1 finalizada!
# Raspagem do conteúdo: 4 da página: 1 finalizada!
# Raspagem do conteúdo: 5 da página: 1 finalizada!
# Raspagem do conteúdo: 6 da página: 1 finalizada!
# Raspagem do conteúdo: 7 da página: 1 finalizada!
# Raspagem do conteúdo: 8 da página: 1 finalizada!
# Raspagem do conteúdo: 9 da página: 1 finalizada!
# Raspagem do conteúdo: 1 da página: 2 finalizada!
# Raspagem do conteúdo: 2 da página: 2 finalizada!
# Raspagem do conteúdo: 3 da página: 2 finalizada!
# Raspagem do conteúdo: 4 da página: 2 finalizada!
# Raspagem do conteúdo: 5 da página: 2 finalizada!
# Raspagem do conteúdo: 6 da página: 2 finalizada!
# Raspagem do conteúdo: 7 da página: 2 finalizada!
# Raspagem do conteúdo: 8 da página: 2 finalizada!
# Raspagem do conteúdo: 9 da página: 2 finalizada!
# Raspagem do conteúdo: 1 da página: 3 finalizada!
# Raspagem do conteúdo: 2 da página: 3 finalizada!
# Raspagem do conteúdo: 3 da página: 3 finalizada!
# Raspagem do conteúdo: 4 da página: 3 finalizada!
# Raspagem do conteúdo: 5 da página: 3 finalizada!
# Raspagem do conteúdo: 6 da página: 3 finalizada!
# Raspagem do conteúdo: 7 da página: 3 finalizada!
# Raspagem do conteúdo: 8 da página: 3 finalizada!
# Raspagem do conteúdo: 9 da página: 3 finalizada!
# Raspagem do conteúdo: 1 da página: 4 finalizada!
# Raspagem do conteúdo: 2 da página: 4 finalizada!
# Raspagem do conteúdo: 3 da página: 4 finalizada!
# Raspagem do conteúdo: 4 da página: 4 finalizada!
# Raspagem do conteúdo: 5 da página: 4 finalizada!
# Raspagem do conteúdo: 6 da página: 4 finalizada!
# Raspagem do conteúdo: 7 da página: 4 finalizada!
# Raspagem do conteúdo: 8 da página: 4 finalizada!
# Raspagem do conteúdo: 1 da página: 5 finalizada!
# Raspagem do conteúdo: 2 da página: 5 finalizada!
# Raspagem do conteúdo: 3 da página: 5 finalizada!
# Raspagem do conteúdo: 4 da página: 5 finalizada!
# Raspagem do conteúdo: 5 da página: 5 finalizada!
# Raspagem do conteúdo: 6 da página: 5 finalizada!
# Raspagem do conteúdo: 7 da página: 5 finalizada!
# Raspagem do conteúdo: 8 da página: 5 finalizada!
# Raspagem do conteúdo: 9 da página: 5 finalizada!
# Raspagem do conteúdo: 1 da página: 6 finalizada!
# Raspagem do conteúdo: 2 da página: 6 finalizada!
# Raspagem do conteúdo: 3 da página: 6 finalizada!
# Raspagem do conteúdo: 4 da página: 6 finalizada!
# Raspagem do conteúdo: 5 da página: 6 finalizada!
# Raspagem do conteúdo: 6 da página: 6 finalizada!
# Raspagem do conteúdo: 7 da página: 6 finalizada!
# Raspagem do conteúdo: 8 da página: 6 finalizada!
# Raspagem do conteúdo: 9 da página: 6 finalizada!
# Raspagem do conteúdo: 1 da página: 7 finalizada!
# Raspagem do conteúdo: 2 da página: 7 finalizada!
# Raspagem do conteúdo: 3 da página: 7 finalizada!
# Raspagem do conteúdo: 4 da página: 7 finalizada!
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[3], line 11, in wait_and_click_element(vire_more_xpath)
#      10 try:
# ---> 11     element = driver.find_element(By.XPATH, vire_more_xpath)
#      12     if element.is_displayed() and element.is_enabled():
#
# File e:\codes\dados\webscrapping\workana\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File e:\codes\dados\webscrapping\workana\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File e:\codes\dados\webscrapping\workana\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="projects"]/div[5]/div[2]/div[2]/div/p/a"}
#   (Session info: chrome=125.0.6422.77); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7143C1F22+60322]
# 	(No symbol) [0x00007FF71433CE99]
# 	(No symbol) [0x00007FF7141F7EBA]
# 	(No symbol) [0x00007FF714247676]
# 	(No symbol) [0x00007FF71424773C]
# 	(No symbol) [0x00007FF71428E967]
# 	(No symbol) [0x00007FF71426C25F]
# 	(No symbol) [0x00007FF71428BC80]
# 	(No symbol) [0x00007FF71426BFC3]
# 	(No symbol) [0x00007FF714239617]
# 	(No symbol) [0x00007FF71423A211]
# 	GetHandleVerifier [0x00007FF7146D946D+3301613]
# 	GetHandleVerifier [0x00007FF714723693+3605267]
# 	GetHandleVerifier [0x00007FF714719410+3563664]
# 	GetHandleVerifier [0x00007FF7144742F6+790390]
# 	(No symbol) [0x00007FF7143474DF]
# 	(No symbol) [0x00007FF7143433D4]
# 	(No symbol) [0x00007FF714343562]
# 	(No symbol) [0x00007FF714332F6F]
# 	BaseThreadInitThunk [0x00007FFA60C6257D+29]
# 	RtlUserThreadStart [0x00007FFA61F8AA48+40]
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 44
#      41 time.sleep(5)
#      43 view_more_xpath = f'{project_xpath}/div[2]/div[2]/div/p/a'
# ---> 44 wait_and_click_element(view_more_xpath)
#      45 time.sleep(4)
#      49 title = driver.find_element(By.XPATH, f'{project_xpath}/div[1]/h2/span/a/span').text
#
# Cell In[3], line 16, in wait_and_click_element(vire_more_xpath)
#      14             break
#      15     except:
# ---> 16         time.sleep(4)
#      17 if not element:
#      18     print(f'não achou elemento {vire_more_xpath}')
#
# KeyboardInterrupt:
